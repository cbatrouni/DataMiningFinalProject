# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.svm import SVC
from scipy import stats
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report


dataset = pd.read_csv('/kaggle/input/censusincomedatacsv/census-income.data.csv')
dataset.head(10)

dataset.shape

dataset.dtypes

dataset.isnull().sum()

dataset.nunique()

dataset.describe().T
# Out:
#                    count           mean            std      min       25%  \
# age              16281.0      38.767459      13.849187     17.0      28.0
# fnlwgt           16281.0  189435.677784  105714.907671  13492.0  116736.0
# educational-num  16281.0      10.072907       2.567545      1.0       9.0
# capital-gain     16281.0    1081.905104    7583.935968      0.0       0.0
# capital-loss     16281.0      87.899269     403.105286      0.0       0.0
# hours-per-week   16281.0      40.392236      12.479332      1.0      40.0
#
#                       50%       75%        max
# age                  37.0      48.0       90.0
# fnlwgt           177831.0  238384.0  1490400.0
# educational-num      10.0      12.0       16.0
# capital-gain          0.0       0.0    99999.0
# capital-loss          0.0       0.0     3770.0
# hours-per-week       40.0      45.0       99.0

# %%
dataset['workclass'].value_counts()
# Out:
# Private             11210
# Self-emp-not-inc     1321
# Local-gov            1043
# ?                     963
# State-gov             683
# Self-emp-inc          579
# Federal-gov           472
# Without-pay             7
# Never-worked            3
# Name: workclass, dtype: int64

# %%
dataset['occupation'].value_counts()
# Out:
# Prof-specialty       2032
# Exec-managerial      2020
# Craft-repair         2013
# Sales                1854
# Adm-clerical         1841
# Other-service        1628
# Machine-op-inspct    1020
# ?                     966
# Transport-moving      758
# Handlers-cleaners     702
# Tech-support          518
# Farming-fishing       496
# Protective-serv       334
# Priv-house-serv        93
# Armed-Forces            6
# Name: occupation, dtype: int64

# %%
dataset['native-country'].value_counts()
# Out:
# United-States                 14662
# Mexico                          308
# ?                               274
# Philippines                      97
# Puerto-Rico                      70
# Germany                          69
# Canada                           61
# India                            51
# El-Salvador                      49
# China                            47
# Cuba                             43
# England                          37
# South                            35
# Dominican-Republic               33
# Italy                            32
# Haiti                            31
# Portugal                         30
# Japan                            30
# Poland                           27
# Columbia                         26
# Jamaica                          25
# Guatemala                        24
# Greece                           20
# Vietnam                          19
# Ecuador                          17
# Iran                             16
# Peru                             15
# Nicaragua                        15
# Taiwan                           14
# Ireland                          13
# Thailand                         12
# Hong                             10
# Outlying-US(Guam-USVI-etc)        9
# France                            9
# Scotland                          9
# Cambodia                          9
# Trinadad&Tobago                   8
# Yugoslavia                        7
# Honduras                          7
# Hungary                           6
# Laos                              5
# Name: native-country, dtype: int64

# %%
dataset['marital-status'].value_counts()
# Out:
# Married-civ-spouse       7403
# Never-married            5434
# Divorced                 2190
# Widowed                   525
# Separated                 505
# Married-spouse-absent     210
# Married-AF-spouse          14
# Name: marital-status, dtype: int64

# %%
dataset['gender'].value_counts()
# Out:
# Male      10860
# Female     5421
# Name: gender, dtype: int64

# %%
dataset['race'].value_counts()
# Out:
# White                 13946
# Black                  1561
# Asian-Pac-Islander      480
# Amer-Indian-Eskimo      159
# Other                   135
# Name: race, dtype: int64

# %%
import warnings
warnings.filterwarnings("ignore")

sns.countplot(dataset['income'], palette='pastel', hue='relationship', data=dataset);

# %%
dataset['education'].value_counts()
# Out:
# HS-grad         5283
# Some-college    3587
# Bachelors       2670
# Masters          934
# Assoc-voc        679
# 11th             637
# Assoc-acdm       534
# 10th             456
# 7th-8th          309
# Prof-school      258
# 9th              242
# 12th             224
# Doctorate        181
# 5th-6th          176
# 1st-4th           79
# Preschool         32
# Name: education, dtype: int64

# %%
dataset['workclass'] = dataset['workclass'].replace('?', 'Private')

dataset['occupation'] = dataset['occupation'].replace('?', 'Prof-specialty')

dataset['native-country'] = dataset['native-country'].replace('?', 'United-States')

dataset.head(8)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18           Private  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29           Private  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2  Married-civ-spouse    Protective-serv        Husband  White    Male
# 3  Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 4       Never-married     Prof-specialty      Own-child  White  Female
# 5       Never-married      Other-service  Not-in-family  White    Male
# 6       Never-married     Prof-specialty      Unmarried  Black    Male
# 7  Married-civ-spouse     Prof-specialty        Husband  White    Male
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0             0             0              40  United-States  <=50K
# 1             0             0              50  United-States  <=50K
# 2             0             0              40  United-States   >50K
# 3          7688             0              40  United-States   >50K
# 4             0             0              30  United-States  <=50K
# 5             0             0              30  United-States  <=50K
# 6             0             0              40  United-States  <=50K
# 7          3103             0              32  United-States   >50K

# %%
# Here we are replacing the exact values with more broad and simpler categories.
dataset.education= dataset.education.replace(['Preschool', '1st-4th', '5th-6th', '7th-8th', '9th','10th', '11th', '12th'], 'school')

dataset.education = dataset.education.replace('Masters', 'grad')

dataset.education = dataset.education.replace('HS-grad', 'high school')

dataset.education = dataset.education.replace('Bachelors', 'undergrad')

dataset.education = dataset.education.replace('Doctorate', 'doc')

dataset.education = dataset.education.replace(['Assoc-voc', 'Assoc-acdm', 'Prof-school', 'Some-college'], 'higher')

#Here we are also categorizing marital status into simpler categories.
dataset['marital-status']= dataset['marital-status'].replace(['Married-civ-spouse', 'Married-AF-spouse'], 'married')

dataset['marital-status']= dataset['marital-status'].replace(['Never-married'], 'not-married')

dataset['marital-status']= dataset['marital-status'].replace(['Divorced', 'Separated','Widowed',
                                                   'Married-spouse-absent'], 'other')

# %%
# Here we are setting the values of '<=50k' and '>50k' to 0 and 1, respectfully.

dataset.income = dataset.income.replace('<=50K', 0)

dataset.income = dataset.income.replace('>50K', 1)

# %%
sns.heatmap(dataset.corr(), annot=True);

# %%
sns.countplot(dataset['education'], hue='gender', data=dataset, palette='hls');

# %%
px.pie(dataset, values='educational-num', names='education', title='% of edu', 
      color_discrete_sequence = px.colors.qualitative.Vivid)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="d96d8032-002c-48a3-bcf6-b7de0c9870c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d96d8032-002c-48a3-bcf6-b7de0c9870c3")) {                    Plotly.newPlot(                        "d96d8032-002c-48a3-bcf6-b7de0c9870c3",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"education=%{label}<br>educational-num=%{value}<extra></extra>","labels":["school","high school","higher","higher","higher","school","high school","higher","higher","school","high school","undergrad","high school","high school","high school","grad","higher","high school","high school","doc","undergrad","higher","school","undergrad","undergrad","high school","high school","high school","high school","higher","higher","school","undergrad","higher","high school","high school","undergrad","school","school","high school","grad","higher","high school","school","higher","higher","school","higher","school","high school","higher","high school","higher","high school","school","higher","high school","undergrad","high school","high school","undergrad","higher","grad","high school","high school","undergrad","higher","higher","high school","high school","higher","higher","high school","higher","higher","school","high school","high school","high school","higher","higher","undergrad","higher","high school","higher","high school","school","high school","higher","grad","undergrad","school","grad","undergrad","grad","high school","undergrad","school","high school","high school","higher","higher","higher","school","high school","school","high school","high school","higher","high school","high school","higher","higher","high school","higher","high school","high school","school","high school","undergrad","undergrad","higher","higher","higher","high school","high school","doc","high school","high school","grad","higher","high school","high school","doc","high school","higher","high school","school","high school","school","grad","higher","high school","high school","grad","high school","higher","high school","undergrad","high school","higher","school","school","school","undergrad","higher","high school","undergrad","higher","undergrad","school","high school","high school","undergrad","grad","higher","doc","high school","high school","high school","high school","grad","undergrad","school","grad","higher","higher","higher","high school","higher","grad","higher","high school","undergrad","high school","higher","high school","high school","undergrad","high school","undergrad","undergrad","higher","school","high school","higher","higher","higher","high school","high school","higher","undergrad","undergrad","undergrad","higher","undergrad","school","high school","undergrad","higher","school","higher","higher","undergrad","undergrad","high school","high school","school","higher","undergrad","undergrad","high school","high school","high school","school","higher","undergrad","high school","school","higher","school","higher","grad","high school","high school","higher","higher","high school","higher","high school","high school","high school","higher","higher","higher","high school","high school","high school","high school","high school","higher","higher","undergrad","undergrad","undergrad","higher","higher","high school","high school","higher","higher","grad","higher","undergrad","grad","higher","high school","school","higher","school","high school","school","higher","grad","high school","high school","high school","school","undergrad","higher","high school","high school","high school","higher","undergrad","higher","high school","higher","higher","high school","high school","school","higher","school","higher","high school","school","high school","higher","high school","higher","school" ...

# %%
dataset.hist(figsize=(15,15), layout=(3,4), sharex=False);

# %%
dataset.plot(kind='box', figsize=(25,25), layout=(3,4), sharex=False, subplots=True);

# %%
X= dataset.drop(['income'], axis=1)
y = dataset['income']

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder

dataset1= dataset.copy()
dataset1= dataset1.apply(LabelEncoder().fit_transform)

ss= StandardScaler().fit(dataset1.drop('income', axis=1))

# %%
X= ss.transform(dataset1.drop('income', axis=1))
y= dataset['income']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=40)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

lr = LogisticRegression()

model = lr.fit(X_train, y_train)
prediction = model.predict(X_test)


print("Training Data Accuracy: {:,.3f}".format(lr.score(X_train, y_train)))

print("Test Data Accuracy: {:,.3f}".format(lr.score(X_test, y_test)))
# Out:
# Training Data Accuracy: 0.838
# Test Data Accuracy: 0.841

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()

model1 = rfc.fit(X_train, y_train)
prediction1 = model1.predict(X_test)


print("Training Data Accuracy: {:,.3f}".format(rfc.score(X_train, y_train)))
print("Test Data Accuracy: {:,.3f}".format(rfc.score(X_test, y_test)))
# Out:
# Training Data Accuracy: 1.000
# Test Data Accuracy: 0.852

# %%
print(confusion_matrix(y_test, prediction1))
# Out:
# [[3448  278]
#  [ 443  716]]

# %%
print(classification_report(y_test, prediction1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      3726
#            1       0.72      0.62      0.67      1159
#
#     accuracy                           0.85      4885
#    macro avg       0.80      0.77      0.79      4885
# weighted avg       0.85      0.85      0.85      4885

# %%
# Here we are creating the random forest instance and
# method in order to use ensemble()

def rforest(X_train, y_train, X_test):

    rforest = BaggingClassifier(base_estimator = RandomForestClassifier(n_estimators = 90))
    
    rforest.fit(X_train, y_train)
    
    y_pred = rforest.predict(X_test)
    
    return y_pred

# %%
# Here we are creating the logistic regression instance and
# method in order to use ensemble()

def lreg(X_train, y_train, X_test):
    
    lreg = BaggingClassifier(base_estimator = LogisticRegression())
    
    lreg.fit(X_train,y_train)
    
    y_pred = lreg.predict(X_test)
    
    return y_pred

# %%
# Here we are creating the naive bayes instance and
# method in order to use ensemble()

def nbayes(X_train, y_train, X_test):
    
    nbayes = BaggingClassifier(base_estimator = GaussianNB())
    
    nbayes.fit(X_train,y_train)
    
    y_pred = nbayes.predict(X_test)
    
    return y_pred

# %%
from sklearn.ensemble import BaggingClassifier


def ensemble(X_train, y_train, X_test):
    ranF = rforest(X_train, y_train, X_test)
    logR = lreg(X_train, y_train, X_test)
    naiB = nbayes(X_train, y_train, X_test)
    
    finalE = []
    
    for i in range (len(X_test)):
        finalE.append(stats.mode([ranF[i], logR[i], naiB[i]])[0][0])
    
    return finalE

# %%
trial_run = ensemble(X_train, y_train, X_test)

# %%
for i in range(4):
    print(['tn', 'fp', 'fn', 'tp'][i],confusion_matrix(trial_run, y_test).ravel()[i])
# Out:
# tn 3499
# fp 514
# fn 227
# tp 645

# %%
print(classification_report(y_test, prediction1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      3726
#            1       0.72      0.62      0.67      1159
#
#     accuracy                           0.85      4885
#    macro avg       0.80      0.77      0.79      4885
# weighted avg       0.85      0.85      0.85      4885

# %%
# Using the precision formula and function: tp/tp+fp
print("Precision Score = ", precision_score(trial_run, y_test))

# Using the recall formula and function= tp/tp+fn
print("Recall Score = ", recall_score(trial_run, y_test))

# Using F1 Score function
print("F1 Score = ", f1_score(trial_run, y_test))

# Using Accuracy Score function
print("Accuracy Score = ", accuracy_score(trial_run, y_test))
# Out:
# Precision Score =  0.5565142364106989
# Recall Score =  0.7396788990825688
# F1 Score =  0.6351550960118169
# Accuracy Score =  0.8483111566018424
